# %%
# importing required libraries
import pandas as pd
import altair as alt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
#loading the dataset
df = pd.read_csv("Superstore.csv")

# %%
# Wrangling
df = df.drop_duplicates()
df = df.drop(df[df.Sales < 100].index)
df = df.drop(df[df.Profit == -6599.9780].index)

def categorise(row):  
    if row['Discount'] > 0:
        return 'Yes'
    return 'No'
df['Discount_Status'] = df.apply(lambda row: categorise(row), axis=1)
df.head()
# Out:
#         Ship Mode   Segment        Country             City       State  \
# 0    Second Class  Consumer  United States        Henderson    Kentucky
# 1    Second Class  Consumer  United States        Henderson    Kentucky
# 3  Standard Class  Consumer  United States  Fort Lauderdale     Florida
# 7  Standard Class  Consumer  United States      Los Angeles  California
# 9  Standard Class  Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 3        33311  South        Furniture       Tables  957.5775         5
# 7        90032   West       Technology       Phones  907.1520         6
# 9        90032   West  Office Supplies   Appliances  114.9000         5
#
#    Discount    Profit Discount_Status
# 0      0.00   41.9136              No
# 1      0.00  219.5820              No
# 3      0.45 -383.0310             Yes
# 7      0.20   90.7152             Yes
# 9      0.00   34.4700              No

# %%
# One-hot encode the data using pandas get_dummies
df = pd.get_dummies(df)

# Labels are the values we want to predict (response variable)
response = np.array(df['Sales'])

# Remove the labels from the features (predictors)
# axis 1 refers to the columns
predictors = df.drop('Sales', axis = 1)

# Saving feature names for later use
predictors_list = list(predictors.columns)

# Convert to numpy array
predictors = np.array(predictors)

# Split the data into training and testing sets
train_predictors, test_predictors, train_response, test_response = train_test_split(df, response, test_size = 0.20, random_state = 42)

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor

# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)

# Train the model on training data
rf.fit(train_predictors, train_response)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_predictors)

# Calculate the absolute errors
errors = (predictions - test_response)**2

# Print out the mean absolute error (mae)
print('Mean Squared Error:', round(np.mean(errors), 2), 'dollars.')
# Out:
# Mean Squared Error: 216603.85 dollars.

# %%
np.amin(errors)
np.amax(errors)
# Out:
# 160668039.94603384

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(predictors_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Quantity             Importance: 0.93
# Variable: Ship Mode_First Class Importance: 0.06
# Variable: Postal Code          Importance: 0.0
# Variable: Discount             Importance: 0.0
# Variable: Profit               Importance: 0.0
# Variable: Ship Mode_Same Day   Importance: 0.0
# Variable: Ship Mode_Second Class Importance: 0.0
# Variable: Ship Mode_Standard Class Importance: 0.0
# Variable: Segment_Consumer     Importance: 0.0
# Variable: Segment_Corporate    Importance: 0.0
# Variable: Segment_Home Office  Importance: 0.0
# Variable: Country_United States Importance: 0.0
# Variable: City_Akron           Importance: 0.0
# Variable: City_Albuquerque     Importance: 0.0
# Variable: City_Alexandria      Importance: 0.0
# Variable: City_Allen           Importance: 0.0
# Variable: City_Allentown       Importance: 0.0
# Variable: City_Amarillo        Importance: 0.0
# Variable: City_Anaheim         Importance: 0.0
# Variable: City_Andover         Importance: 0.0
# Variable: City_Ann Arbor       Importance: 0.0
# Variable: City_Apopka          Importance: 0.0
# Variable: City_Apple Valley    Importance: 0.0
# Variable: City_Appleton        Importance: 0.0
# Variable: City_Arlington       Importance: 0.0
# Variable: City_Arvada          Importance: 0.0
# Variable: City_Asheville       Importance: 0.0
# Variable: City_Athens          Importance: 0.0
# Variable: City_Atlanta         Importance: 0.0
# Variable: City_Auburn          Importance: 0.0
# Variable: City_Aurora          Importance: 0.0
# Variable: City_Austin          Importance: 0.0
# Variable: City_Avondale        Importance: 0.0
# Variable: City_Bakersfield     Importance: 0.0
# Variable: City_Baltimore       Importance: 0.0
# Variable: City_Bangor          Importance: 0.0
# Variable: City_Bayonne         Importance: 0.0
# Variable: City_Beaumont        Importance: 0.0
# Variable: City_Bedford         Importance: 0.0
# Variable: City_Belleville      Importance: 0.0
# Variable: City_Bellingham      Importance: 0.0
# Variable: City_Bethlehem       Importance: 0.0
# Variable: City_Beverly         Importance: 0.0
# Variable: City_Bloomington     Importance: 0.0
# Variable: City_Boise           Importance: 0.0
# Variable: City_Bolingbrook     Importance: 0.0
# Variable: City_Bossier City    Importance: 0.0
# Variable: City_Bowling Green   Importance: 0.0
# Variable: City_Boynton Beach   Importance: 0.0
# Variable: City_Brentwood       Importance: 0.0
# Variable: City_Bristol         Importance: 0.0
# Variable: City_Broken Arrow    Importance: 0.0
# Variable: City_Broomfield      Importance: 0.0
# Variable: City_Brownsville     Importance: 0.0
# Variable: City_Bryan           Importance: 0.0
# Variable: City_Buffalo         Importance: 0.0
# Variable: City_Buffalo Grove   Importance: 0.0
# Variable: City_Burbank         Importance: 0.0
# Variable: City_Burlington      Importance: 0.0
# Variable: City_Caldwell        Importance: 0.0
# Variable: City_Camarillo       Importance: 0.0
# Variable: City_Cambridge       Importance: 0.0
# Variable: City_Canton          Importance: 0.0
# Variable: City_Carlsbad        Importance: 0.0
# Variable: City_Carol Stream    Importance: 0.0
# Variable: City_Carrollton      Importance: 0.0
# Variable: City_Cary            Importance: 0.0
# Variable: City_Cedar Hill      Importance: 0.0
# Variable: City_Cedar Rapids    Importance: 0.0
# Variable: City_Champaign       Importance: 0.0
# Variable: City_Chandler        Importance: 0.0
# Variable: City_Charlotte       Importance: 0.0
# Variable: City_Chattanooga     Importance: 0.0
# Variable: City_Chesapeake      Importance: 0.0
# Variable: City_Chester         Importance: 0.0
# Variable: City_Cheyenne        Importance: 0.0
# Variable: City_Chicago         Importance: 0.0
# Variable: City_Chico           Importance: 0.0
# Variable: City_Chula Vista     Importance: 0.0
# Variable: City_Cincinnati      Importance: 0.0
# Variable: City_Citrus Heights  Importance: 0.0
# Variable: City_Clarksville     Importance: 0.0
# Variable: City_Cleveland       Importance: 0.0
# Variable: City_Clifton         Importance: 0.0
# Variable: City_Clinton         Importance: 0.0
# Variable: City_Clovis          Importance: 0.0
# Variable: City_College Station Importance: 0.0
# Variable: City_Colorado Springs Importance: 0.0
# Variable: City_Columbia        Importance: 0.0
# Variable: City_Columbus        Importance: 0.0
# Variable: City_Commerce City   Importance: 0.0
# Variable: City_Concord         Importance: 0.0
# Variable: City_Conroe          Importance: 0.0
# Variable: City_Conway          Importance: 0.0
# Variable: City_Coon Rapids     Importance: 0.0
# Variable: City_Coral Springs   Importance: 0.0
# Variable: City_Costa Mesa      Importance: 0.0
# Variable: City_Cottage Grove   Importance: 0.0
# Variable: City_Covington       Importance: 0.0
# Variable: City_Cranston        Importance: 0.0
# Variable: City_Dallas          Importance: 0.0
# Variable: City_Danville        Importance: 0.0
# Variable: City_Daytona Beach   Importance: 0.0
# Variable: City_Dearborn        Importance: 0.0
# Variable: City_Dearborn Heights Importance: 0.0
# Variable: City_Decatur         Importance: 0.0
# Variable: City_Delray Beach    Importance: 0.0
# Variable: City_Deltona         Importance: 0.0
# Variable: City_Denver          Importance: 0.0
# Variable: City_Des Moines      Importance: 0.0
# Variable: City_Des Plaines     Importance: 0.0
# Variable: City_Detroit         Importance: 0.0
# Variable: City_Dover           Importance: 0.0
# Variable: City_Draper          Importance: 0.0
# Variable: City_Dublin          Importance: 0.0
# Variable: City_Dubuque         Importance: 0.0
# Variable: City_Durham          Importance: 0.0
# Variable: City_East Orange     Importance: 0.0
# Variable: City_East Point      Importance: 0.0
# Variable: City_Eau Claire      Importance: 0.0
# Variable: City_Edmond          Importance: 0.0
# Variable: City_Edmonds         Importance: 0.0
# Variable: City_El Cajon        Importance: 0.0
# Variable: City_El Paso         Importance: 0.0
# Variable: City_Elkhart         Importance: 0.0
# Variable: City_Elmhurst        Importance: 0.0
# Variable: City_Encinitas       Importance: 0.0
# Variable: City_Englewood       Importance: 0.0
# Variable: City_Eugene          Importance: 0.0
# Variable: City_Evanston        Importance: 0.0
# Variable: City_Everett         Importance: 0.0
# Variable: City_Fairfield       Importance: 0.0
# Variable: City_Fargo           Importance: 0.0
# Variable: City_Farmington      Importance: 0.0
# Variable: City_Fayetteville    Importance: 0.0
# Variable: City_Florence        Importance: 0.0
# Variable: City_Fort Collins    Importance: 0.0
# Variable: City_Fort Lauderdale Importance: 0.0
# Variable: City_Fort Worth      Importance: 0.0
# Variable: City_Franklin        Importance: 0.0
# Variable: City_Freeport        Importance: 0.0
# Variable: City_Fremont         Importance: 0.0
# Variable: City_Fresno          Importance: 0.0
# Variable: City_Gaithersburg    Importance: 0.0
# Variable: City_Garden City     Importance: 0.0
# Variable: City_Gastonia        Importance: 0.0
# Variable: City_Georgetown      Importance: 0.0
# Variable: City_Gilbert         Importance: 0.0
# Variable: City_Gladstone       Importance: 0.0
# Variable: City_Glendale        Importance: 0.0
# Variable: City_Glenview        Importance: 0.0
# Variable: City_Grand Prairie   Importance: 0.0
# Variable: City_Grand Rapids    Importance: 0.0
# Variable: City_Great Falls     Importance: 0.0
# Variable: City_Green Bay       Importance: 0.0
# Variable: City_Greensboro      Importance: 0.0
# Variable: City_Greenville      Importance: 0.0
# Variable: City_Greenwood       Importance: 0.0
# Variable: City_Gresham         Importance: 0.0
# Variable: City_Grove City      Importance: 0.0
# Variable: City_Hackensack      Importance: 0.0
# Variable: City_Haltom City     Importance: 0.0
# Variable: City_Hamilton        Importance: 0.0
# Variable: City_Hampton         Importance: 0.0
# Variable: City_Harlingen       Importance: 0.0
# Variable: City_Harrisonburg    Importance: 0.0
# Variable: City_Hattiesburg     Importance: 0.0
# Variable: City_Helena          Importance: 0.0
# Variable: City_Hempstead       Importance: 0.0
# Variable: City_Henderson       Importance: 0.0
# Variable: City_Hendersonville  Importance: 0.0
# Variable: City_Hesperia        Importance: 0.0
# Variable: City_Hialeah         Importance: 0.0
# Variable: City_Highland Park   Importance: 0.0
# Variable: City_Holland         Importance: 0.0
# Variable: City_Hollywood       Importance: 0.0
# Variable: City_Holyoke         Importance: 0.0
# Variable: City_Hoover          Importance: 0.0
# Variable: City_Hot Springs     Importance: 0.0
# Variable: City_Houston         Importance: 0.0
# Variable: City_Huntington Beach Importance: 0.0
# Variable: City_Huntsville      Importance: 0.0
# Variable: City_Independence    Importance: 0.0
# Variable: City_Indianapolis    Importance: 0.0
# Variable: City_Inglewood       Importance: 0.0
# Variable: City_Irving          Importance: 0.0
# Variable: City_Jackson         Importance: 0.0
# Variable: City_Jacksonville    Importance: 0.0
# Variable: City_Jamestown       Importance: 0.0
# Variable: City_Johnson City    Importance: 0.0
# Variable: City_Jonesboro       Importance: 0.0
# Variable: City_Kenosha         Importance: 0.0
# Variable: City_Kent            Importance: 0.0
# Variable: City_Kirkwood        Importance: 0.0
# Variable: City_Kissimmee       Importance: 0.0
# Variable: City_Knoxville       Importance: 0.0
# Variable: City_La Crosse       Importance: 0.0
# Variable: City_La Mesa         Importance: 0.0
# Variable: City_La Porte        Importance: 0.0
# Variable: City_Lafayette       Importance: 0.0
# Variable: City_Laguna Niguel   Importance: 0.0
# Variable: City_Lake Charles    Importance: 0.0
# Variable: City_Lake Elsinore   Importance: 0.0
# Variable: City_Lake Forest     Importance: 0.0
# Variable: City_Lakeland        Importance: 0.0
# Variable: City_Lakeville       Importance: 0.0
# Variable: City_Lakewood        Importance: 0.0
# Variable: City_Lancaster       Importance: 0.0
# Variable: City_Lansing         Importance: 0.0
# Variable: City_Laredo          Importance: 0.0
# Variable: City_Las Vegas       Importance: 0.0
# Variable: City_Laurel          Importance: 0.0
# Variable: City_Lawrence        Importance: 0.0
# Variable: City_Lawton          Importance: 0.0
# Variable: City_League City     Importance: 0.0
# Variable: City_Lebanon         Importance: 0.0
# Variable: City_Lehi            Importance: 0.0
# Variable: City_Leominster      Importance: 0.0
# Variable: City_Lincoln Park    Importance: 0.0
# Variable: City_Linden          Importance: 0.0
# Variable: City_Little Rock     Importance: 0.0
# Variable: City_Long Beach      Importance: 0.0
# Variable: City_Longmont        Importance: 0.0
# Variable: City_Lorain          Importance: 0.0
# Variable: City_Los Angeles     Importance: 0.0
# Variable: City_Louisville      Importance: 0.0
# Variable: City_Lowell          Importance: 0.0
# Variable: City_Lubbock         Importance: 0.0
# Variable: City_Macon           Importance: 0.0
# Variable: City_Madison         Importance: 0.0
# Variable: City_Malden          Importance: 0.0
# Variable: City_Manchester      Importance: 0.0
# Variable: City_Manhattan       Importance: 0.0
# Variable: City_Mansfield       Importance: 0.0
# Variable: City_Manteca         Importance: 0.0
# Variable: City_Maple Grove     Importance: 0.0
# Variable: City_Marietta        Importance: 0.0
# Variable: City_Marion          Importance: 0.0
# Variable: City_Marlborough     Importance: 0.0
# Variable: City_Mcallen         Importance: 0.0
# Variable: City_Medina          Importance: 0.0
# Variable: City_Memphis         Importance: 0.0
# Variable: City_Mentor          Importance: 0.0
# Variable: City_Meriden         Importance: 0.0
# Variable: City_Meridian        Importance: 0.0
# Variable: City_Mesa            Importance: 0.0
# Variable: City_Miami           Importance: 0.0
# Variable: City_Middletown      Importance: 0.0
# Variable: City_Midland         Importance: 0.0
# Variable: City_Milford         Importance: 0.0
# Variable: City_Milwaukee       Importance: 0.0
# Variable: City_Minneapolis     Importance: 0.0
# Variable: City_Miramar         Importance: 0.0
# Variable: City_Mishawaka       Importance: 0.0
# Variable: City_Mission Viejo   Importance: 0.0
# Variable: City_Missoula        Importance: 0.0
# Variable: City_Mobile          Importance: 0.0
# Variable: City_Modesto         Importance: 0.0
# Variable: City_Monroe          Importance: 0.0
# Variable: City_Montgomery      Importance: 0.0
# Variable: City_Moorhead        Importance: 0.0
# Variable: City_Moreno Valley   Importance: 0.0
# Variable: City_Morgan Hill     Importance: 0.0
# Variable: City_Morristown      Importance: 0.0
# Variable: City_Mount Pleasant  Importance: 0.0
# Variable: City_Mount Vernon    Importance: 0.0
# Variable: City_Murfreesboro    Importance: 0.0
# Variable: City_Murray          Importance: 0.0
# Variable: City_Murrieta        Importance: 0.0
# Variable: City_Muskogee        Importance: 0.0
# Variable: City_Naperville      Importance: 0.0
# Variable: City_Nashville       Importance: 0.0
# Variable: City_New Bedford     Importance: 0.0
# Variable: City_New Rochelle    Importance: 0.0
# Variable: City_New York City   Importance: 0.0
# Variable: City_Newark          Importance: 0.0
# Variable: City_Newport News    Importance: 0.0
# Variable: City_Niagara Falls   Importance: 0.0
# Variable: City_Noblesville     Importance: 0.0
# Variable: City_Normal          Importance: 0.0
# Variable: City_Norman          Importance: 0.0
# Variable: City_North Charleston Importance: 0.0
# Variable: City_North Las Vegas Importance: 0.0
# Variable: City_Norwich         Importance: 0.0
# Variable: City_Oak Park        Importance: 0.0
# Variable: City_Oakland         Importance: 0.0
# Variable: City_Oceanside       Importance: 0.0
# Variable: City_Odessa          Importance: 0.0
# Variable: City_Oklahoma City   Importance: 0.0
# Variable: City_Olathe          Importance: 0.0
# Variable: City_Olympia         Importance: 0.0
# Variable: City_Omaha           Importance: 0.0
# Variable: City_Ontario         Importance: 0.0
# Variable: City_Orem            Importance: 0.0
# Variable: City_Orland Park     Importance: 0.0
# Variable: City_Orlando         Importance: 0.0
# Variable: City_Oswego          Importance: 0.0
# Variable: City_Overland Park   Importance: 0.0
# Variable: City_Oxnard          Importance: 0.0
# Variable: City_Palatine        Importance: 0.0
# Variable: City_Palm Coast      Importance: 0.0
# Variable: City_Park Ridge      Importance: 0.0
# Variable: City_Parker          Importance: 0.0
# Variable: City_Parma           Importance: 0.0
# Variable: City_Pasadena        Importance: 0.0
# Variable: City_Pasco           Importance: 0.0
# Variable: City_Passaic         Importance: 0.0
# Variable: City_Paterson        Importance: 0.0
# Variable: City_Pearland        Importance: 0.0
# Variable: City_Pembroke Pines  Importance: 0.0
# Variable: City_Peoria          Importance: 0.0
# Variable: City_Perth Amboy     Importance: 0.0
# Variable: City_Pharr           Importance: 0.0
# Variable: City_Philadelphia    Importance: 0.0
# Variable: City_Phoenix         Importance: 0.0
# Variable: City_Pico Rivera     Importance: 0.0
# Variable: City_Pine Bluff      Importance: 0.0
# Variable: City_Plainfield      Importance: 0.0
# Variable: City_Plano           Importance: 0.0
# Variable: City_Plantation      Importance: 0.0
# Variable: City_Pleasant Grove  Importance: 0.0
# Variable: City_Pocatello       Importance: 0.0
# Variable: City_Pomona          Importance: 0.0
# Variable: City_Port Arthur     Importance: 0.0
# Variable: City_Port Saint Lucie Importance: 0.0
# Variable: City_Portland        Importance: 0.0
# Variable: City_Providence      Importance: 0.0
# Variable: City_Provo           Importance: 0.0
# Variable: City_Pueblo          Importance: 0.0
# Variable: City_Quincy          Importance: 0.0
# Variable: City_Raleigh         Importance: 0.0
# Variable: City_Rancho Cucamonga Importance: 0.0
# Variable: City_Rapid City      Importance: 0.0
# Variable: City_Reading         Importance: 0.0
# Variable: City_Redding         Importance: 0.0
# Variable: City_Redlands        Importance: 0.0
# Variable: City_Redmond         Importance: 0.0
# Variable: City_Redondo Beach   Importance: 0.0
# Variable: City_Reno            Importance: 0.0
# Variable: City_Renton          Importance: 0.0
# Variable: City_Revere          Importance: 0.0
# Variable: City_Richardson      Importance: 0.0
# Variable: City_Richmond        Importance: 0.0
# Variable: City_Rio Rancho      Importance: 0.0
# Variable: City_Riverside       Importance: 0.0
# Variable: City_Rochester       Importance: 0.0
# Variable: City_Rochester Hills Importance: 0.0
# Variable: City_Rockford        Importance: 0.0
# Variable: City_Rockville       Importance: 0.0
# Variable: City_Rome            Importance: 0.0
# Variable: City_Roseville       Importance: 0.0
# Variable: City_Roswell         Importance: 0.0
# Variable: City_Round Rock      Importance: 0.0
# Variable: City_Sacramento      Importance: 0.0
# Variable: City_Saginaw         Importance: 0.0
# Variable: City_Saint Charles   Importance: 0.0
# Variable: City_Saint Cloud     Importance: 0.0
# Variable: City_Saint Louis     Importance: 0.0
# Variable: City_Saint Paul      Importance: 0.0
# Variable: City_Saint Peters    Importance: 0.0
# Variable: City_Saint Petersburg Importance: 0.0
# Variable: City_Salem           Importance: 0.0
# Variable: City_Salinas         Importance: 0.0
# Variable: City_Salt Lake City  Importance: 0.0
# Variable: City_San Angelo      Importance: 0.0
# Variable: City_San Antonio     Importance: 0.0
# Variable: City_San Bernardino  Importance: 0.0
# Variable: City_San Diego       Importance: 0.0
# Variable: City_San Francisco   Importance: 0.0
# Variable: City_San Gabriel     Importance: 0.0
# Variable: City_San Jose        Importance: 0.0
# Variable: City_Sandy Springs   Importance: 0.0
# Variable: City_Sanford         Importance: 0.0
# Variable: City_Santa Ana       Importance: 0.0
# Variable: City_Santa Barbara   Importance: 0.0
# Variable: City_Santa Maria     Importance: 0.0
# Variable: City_Scottsdale      Importance: 0.0
# Variable: City_Seattle         Importance: 0.0
# Variable: City_Sioux Falls     Importance: 0.0
# Variable: City_Skokie          Importance: 0.0
# Variable: City_Smyrna          Importance: 0.0
# Variable: City_South Bend      Importance: 0.0
# Variable: City_Southaven       Importance: 0.0
# Variable: City_Sparks          Importance: 0.0
# Variable: City_Spokane         Importance: 0.0
# Variable: City_Springfield     Importance: 0.0
# Variable: City_Stockton        Importance: 0.0
# Variable: City_Suffolk         Importance: 0.0
# Variable: City_Summerville     Importance: 0.0
# Variable: City_Sunnyvale       Importance: 0.0
# Variable: City_Superior        Importance: 0.0
# Variable: City_Tallahassee     Importance: 0.0
# Variable: City_Tamarac         Importance: 0.0
# Variable: City_Tampa           Importance: 0.0
# Variable: City_Taylor          Importance: 0.0
# Variable: City_Temecula        Importance: 0.0
# Variable: City_Tempe           Importance: 0.0
# Variable: City_Texarkana       Importance: 0.0
# Variable: City_Texas City      Importance: 0.0
# Variable: City_Thornton        Importance: 0.0
# Variable: City_Thousand Oaks   Importance: 0.0
# Variable: City_Tigard          Importance: 0.0
# Variable: City_Toledo          Importance: 0.0
# Variable: City_Torrance        Importance: 0.0
# Variable: City_Trenton         Importance: 0.0
# Variable: City_Troy            Importance: 0.0
# Variable: City_Tucson          Importance: 0.0
# Variable: City_Tulsa           Importance: 0.0
# Variable: City_Tuscaloosa      Importance: 0.0
# Variable: City_Twin Falls      Importance: 0.0
# Variable: City_Tyler           Importance: 0.0
# Variable: City_Utica           Importance: 0.0
# Variable: City_Vacaville       Importance: 0.0
# Variable: City_Vallejo         Importance: 0.0
# Variable: City_Vancouver       Importance: 0.0
# Variable: City_Vineland        Importance: 0.0
# Variable: City_Virginia Beach  Importance: 0.0
# Variable: City_Visalia         Importance: 0.0
# Variable: City_Waco            Importance: 0.0
# Variable: City_Warner Robins   Importance: 0.0
# Variable: City_Warwick         Importance: 0.0
# Variable: City_Washington      Importance: 0.0
# Variable: City_Waterbury       Importance: 0.0
# Variable: City_Watertown       Importance: 0.0
# Variable: City_Wausau          Importance: 0.0
# Variable: City_Waynesboro      Importance: 0.0
# Variable: City_West Allis      Importance: 0.0
# Variable: City_Westfield       Importance: 0.0
# Variable: City_Westland        Importance: 0.0
# Variable: City_Westminster     Importance: 0.0
# Variable: City_Wheeling        Importance: 0.0
# Variable: City_Whittier        Importance: 0.0
# Variable: City_Wichita         Importance: 0.0
# Variable: City_Wilmington      Importance: 0.0
# Variable: City_Wilson          Importance: 0.0
# Variable: City_Woodbury        Importance: 0.0
# Variable: City_Woodland        Importance: 0.0
# Variable: City_Woodstock       Importance: 0.0
# Variable: City_Yonkers         Importance: 0.0
# Variable: City_York            Importance: 0.0
# Variable: City_Yuma            Importance: 0.0
# Variable: State_Alabama        Importance: 0.0
# Variable: State_Arizona        Importance: 0.0
# Variable: State_Arkansas       Importance: 0.0
# Variable: State_California     Importance: 0.0
# Variable: State_Colorado       Importance: 0.0
# Variable: State_Connecticut    Importance: 0.0
# Variable: State_Delaware       Importance: 0.0
# Variable: State_District of Columbia Importance: 0.0
# Variable: State_Florida        Importance: 0.0
# Variable: State_Georgia        Importance: 0.0
# Variable: State_Idaho          Importance: 0.0
# Variable: State_Illinois       Importance: 0.0
# Variable: State_Indiana        Importance: 0.0
# Variable: State_Iowa           Importance: 0.0
# Variable: State_Kansas         Importance: 0.0
# Variable: State_Kentucky       Importance: 0.0
# Variable: State_Louisiana      Importance: 0.0
# Variable: State_Maine          Importance: 0.0
# Variable: State_Maryland       Importance: 0.0
# Variable: State_Massachusetts  Importance: 0.0
# Variable: State_Michigan       Importance: 0.0
# Variable: State_Minnesota      Importance: 0.0
# Variable: State_Mississippi    Importance: 0.0
# Variable: State_Missouri       Importance: 0.0
# Variable: State_Montana        Importance: 0.0
# Variable: State_Nebraska       Importance: 0.0
# Variable: State_Nevada         Importance: 0.0
# Variable: State_New Hampshire  Importance: 0.0
# Variable: State_New Jersey     Importance: 0.0
# Variable: State_New Mexico     Importance: 0.0
# Variable: State_New York       Importance: 0.0
# Variable: State_North Carolina Importance: 0.0
# Variable: State_North Dakota   Importance: 0.0
# Variable: State_Ohio           Importance: 0.0
# Variable: State_Oklahoma       Importance: 0.0
# Variable: State_Oregon         Importance: 0.0
# Variable: State_Pennsylvania   Importance: 0.0
# Variable: State_Rhode Island   Importance: 0.0
# Variable: State_South Carolina Importance: 0.0
# Variable: State_South Dakota   Importance: 0.0
# Variable: State_Tennessee      Importance: 0.0
# Variable: State_Texas          Importance: 0.0
# Variable: State_Utah           Importance: 0.0
# Variable: State_Vermont        Importance: 0.0
# Variable: State_Virginia       Importance: 0.0
# Variable: State_Washington     Importance: 0.0
# Variable: State_West Virginia  Importance: 0.0
# Variable: State_Wisconsin      Importance: 0.0
# Variable: State_Wyoming        Importance: 0.0
# Variable: Region_Central       Importance: 0.0
# Variable: Region_East          Importance: 0.0
# Variable: Region_South         Importance: 0.0
# Variable: Region_West          Importance: 0.0
# Variable: Category_Furniture   Importance: 0.0
# Variable: Category_Office Supplies Importance: 0.0
# Variable: Category_Technology  Importance: 0.0
# Variable: Sub-Category_Accessories Importance: 0.0
# Variable: Sub-Category_Appliances Importance: 0.0
# Variable: Sub-Category_Art     Importance: 0.0
# Variable: Sub-Category_Binders Importance: 0.0
# Variable: Sub-Category_Bookcases Importance: 0.0
# Variable: Sub-Category_Chairs  Importance: 0.0
# Variable: Sub-Category_Copiers Importance: 0.0
# Variable: Sub-Category_Envelopes Importance: 0.0
# Variable: Sub-Category_Furnishings Importance: 0.0
# Variable: Sub-Category_Labels  Importance: 0.0
# Variable: Sub-Category_Machines Importance: 0.0
# Variable: Sub-Category_Paper   Importance: 0.0
# Variable: Sub-Category_Phones  Importance: 0.0
# Variable: Sub-Category_Storage Importance: 0.0
# Variable: Sub-Category_Supplies Importance: 0.0
# Variable: Sub-Category_Tables  Importance: 0.0
# Variable: Discount_Status_No   Importance: 0.0
# Variable: Discount_Status_Yes  Importance: 0.0

# %%
test = np.array([1, 2, 3])

# %%
np.amin(test)
# Out:
# 1

# %%
np.amax(test)
# Out:
# 3

# %%
errors
# Out:
# array([1.19443041e-02, 1.85547987e-04, 1.08489867e-01, 4.78938739e-01,
#        5.73360169e-01, 7.32324782e-04, 5.62828176e-02, 1.57529610e-03,
#        1.77492005e-03, 2.16743173e-02, 1.78607664e-03, 2.11254597e-02,
